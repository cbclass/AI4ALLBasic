# %%
from regression_sim import WidgetRegression
import numpy as np

x=[0.0956285,0.135945,0.353652,0.255281,0.337526,0.640704,0.504585,0.440735,0.631028,0.572972]
y=[0.9223158,0.702211,0.693263,.510737,0.492842,0.550105,0.167158,0.342526,0.256632,0.007895]

data=np.array([x,y]).transpose()
  
widget_instance = WidgetRegression(data)
display(widget_instance.layout)
