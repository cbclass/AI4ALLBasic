# %%
from questions import *

Q1 = create_multipleChoice_widget_new(
    "Welche Probleme können auftreten, wenn in einem Datensatz unterschiedliche Merkmalsausprägungen für dasselbe Geschlecht verwendet werden?  \n"+
    '**A.** Es hat keinen Einfluss auf die Datenverarbeitung, da alle Ausprägungen automatisch erkannt werden.  \n'+
    '**B.** Es kann zu Schwierigkeiten bei der Datenaggregation und -filterung führen, da die Konsistenz der Daten beeinträchtigt wird.  \n'+
    '**C.** Es erleichtert die Datenanalyse, da mehr Variationen vorhanden sind.  \n'
,
    [],
    [
  'A','B','C'    ],
    'B',
    0
)
display(Q1)
