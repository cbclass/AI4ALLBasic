# %%
from regression_sim import WidgetRegression
import numpy as np

from regression_sim import generateData

data=generateData(n=15)
  
widget_instance = WidgetRegression(data)
display(widget_instance.layout)
