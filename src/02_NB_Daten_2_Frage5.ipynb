# %%
from questions import *

Q1= create_multipleChoice_widget_new("Warum ist es wichtig, die Anzahl der gelöschten Zeilen zu dokumentieren?  \n"+
                                     '**A.** Um die Performance zu messen und pandas Informationen darüber zu geben.  \n'+
     '**B.** Um die Vorverarbeitungsschritte zu überprüfen und eventuell entstehenden Bias rechtzeitig zu erkennen.  \n'+
     '**C.** Es ist nicht wichtig.  \n', [], 
    ['A','B','C'], 
    'B', 1)

display(Q1)
