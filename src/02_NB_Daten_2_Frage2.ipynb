# %%
from questions_2 import *

Q1 = create_multipleChoice_widget_new(
    "Welches Problem könnte auftreten, wenn fehlende Werte in der Zufriedenheitsspalte durch den Durchschnittswert ersetzt werden?  \n"+
    "**A.** Der Durchschnittswert könnte zu einer neuen Merkmalsausprägung zwischen den diskreten Werten führen, die in der ursprünglichen Umfrage nicht existierte.  \n"+
    "**B.** Der Durchschnittswert ist immer repräsentativ für die vorhandenen diskreten Daten.  \n"+
    "**C.** Das Ersetzen durch den Durchschnittswert hat keinen Einfluss auf die Datenqualität.  \n",
    [],
    [
        'A','B','C'
    ],
    'A',
    0
)
display(Q1)
