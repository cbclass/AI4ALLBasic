# %% [markdown]
# <img src="./src/logo.png" width="250">

# %% [markdown]
# **Baustein:** Clustering  $\rightarrow$ **Subbaustein:** $k$-Means Clustering **Interaktive Übungsserie**
#
# **Version:** 2.0, **Lizenz:** <a rel="license" href="http://creativecommons.org/licenses/by-nc-nd/4.0/">CC BY-NC-ND 4.0</a>
#
# ***

# %% [markdown]
# # k-Means Clustering: Interaktive Aufgabe

# %% [markdown]
# ---
# ## 1. Einleitung
#
# In dieser Übung lernen Sie die Funktionsweise und Hyperparameter des $k$-Means Clusterinh Algorithmus kennen. Sie beobachten auch den Einfluss der unterschiedlichen Clusterzentren. Sie werden auch sehen, dass $k$-Means nicht für alle Datensätze geeignet ist.
#
# Um die **Auswirkungen** der einzelnen Parameter auf den $k$-Means Clustering Algorithmus **testen** und **beobachten** zu können, stellen wir Ihnen zwei Widgets zur Verfügung. In diesen Widgets können Sie **die folgenden Parameter einstellen**:
#
# - **Hyperparemeter:**
#     - **Number of Clusters:** $k$, also die Anzahl Cluster
#     - **Iterations:** die Anzahl durchgeführter Iterationen. Sie können so den Algorithmus Schritt für Schritt nachvollziehen
# - **Datasets:** es stehen Ihnen jeweils sechs verschiedene Datensätze zur Verfügung
# - **Initial Cluster Centers:** diese können geändert werden
# - **Options:** durch Auswahl von **Show Cluster Areas** können Sie sich die Clusterflächen / (linearen) Grenzen der Cluster anzeigen lassen.

# %% [markdown]
# ---
# ## 2. Hyperparameter

# %% [markdown]
# Verwenden Sie das folgende Widget um die folgenden Aufgaben zu bearbeiten. Testen Sie hierfür jeweils verschiedene Werte für die in den Aufgaben genannten Parameter aus, um die Fragen zu beantworten.

# %%
# %run src/Clustering_widget.py

# %% [markdown]
# #### Aufgabe 1: Auswahl des Parameters $k$
#
# - Wählen Sie den ersten Datensatz Dataset 1 aus.
# - Sehen Sie sich die Daten an und bestimmen Sie visuell eine geeignete Anzahl $k$ für die Cluster.
# - Verändern Sie die Anzahl Iterationen, bis keine Veränderungen der Clusterzentren mehr erfolgten.
#
# Welchen Wert haben Sie für $k$ gewählt? Wie viele Iterationen werden benötigt?

# %% [markdown]
# **Antwort:**

# %% [markdown]
# - Ändern Sie die Anzahl $k$ auf 4 und führen Sie das Clustering durch. Wieviele Iterationen brauchen Sie, bis die Clusterzentren stabil sind?
#
# **Hinweis:** das können Sie am Besten beobachten, wenn Sie sich die Clusterfächen ansehen  und die Grenzen beobachten.

# %% [markdown]
# **Antwort:**

# %% [markdown]
# #### Aufgabe 2: Initiale Clusterzentren.
#
# Wählen Sie wieder 3 für $k$ und wählen Sie als Initial Cluster Centers **Centers 2**.
#
# Vergleichen Sie die identifizierten Cluster mit den Clustern für $k=3$ aus **Aufgabe 1**.
#
# - Wieviele Iterationen benötigen Sie nun?
# - Wenn Sie die Cluster mit Ihrer visuellen Einschätzung vergleichen, ist diese Lösung besser als zuvor?
# - Vergleichen Sie die initialen Clusterzentren. Könenn Sie den Unterschied erklären?

# %% [markdown]
# **Antwort:**

# %% [markdown]
# #### Aufgabe 3: andere Datensätze
#
# Wiederholen Sie obige Schritte bei den anderen Datensätzen und versuchen Sie, eine visuelle gute Clusteraufteilung zu finden. Bestimmen Sie hierzu das geeignete $k$. Wie wirken sich die unterschiedlichen Clusterzentren aus?

# %% [markdown]
# **Notizen:**

# %% [markdown]
# ---
# ## 3. Eignung von Datensätzen
#
# $k$-Means Clustering eignet sich insbesondere zum Clustering von kugelförmigen und konvexen Strukturen. In dieser Aufgabe geht es darum, Ergebnisse des $k$-Means Clustering bei verschiedenen Strukturen der Daten zu beobachten.

# %%
# %run src/Clustering_widget2.py

# %% [markdown]
# #### Aufgabe 4: Verschiedene Strukturen
#
# Testen Sie die sechs verschiedenen Datensätze und suchen Sie eine geeignete Anzahl von Clustern. Die initialen Clusterzentren können Sie mit **Random** verändern.
#
# Untersuchen Sie, welche Datensets mit $k$-Means gut geclustert werden können. Ist die Anzahl von $k$ visuell einfach zu bestimmen? Gibt es Strukturen, bei denen es grundsätzlich nicht gut funktioniert? Gibt es vielleicht auch andere, bei denen es für bestimmte Initialwerte funktionieren kann?

# %% [markdown]
# **Notizen:**

# %% [markdown]
# ---
#
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-nd/4.0/"><img alt="Creative Commons Lizenzvertrag" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-nd/4.0/88x31.png" /></a><br /><span xmlns:dct="http://purl.org/dc/terms/" property="dct:title">Die Übungsserie begleitend zum AI4ALL-Kurs</span> der <span xmlns:cc="http://creativecommons.org/ns#" property="cc:attributionName">EAH Jena</span> ist lizenziert unter einer <a rel="license" href="http://creativecommons.org/licenses/by-nc-nd/4.0/">Creative Commons Namensnennung - Nicht kommerziell - Keine Bearbeitungen 4.0 International Lizenz</a>.
#
# Der AI4ALL-Kurs entsteht im Rahmen des Projekts MoVeKI2EAH. Das Projekt MoVeKI2EAH wird durch das BMBF (Bundesministerium für Bildung und Forschung) und den Freistaat Thüringen im Rahmen der Bund-Länder-Initiative zur Förderung von Künstlicher Intelligenz in der Hochschulbildung gefördert (12/2021 bis 11/2025, Föderkennzeichen 16DHBKI081).
